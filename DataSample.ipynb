# %%
import pandas as pd
from urllib.request import urlopen
import numpy as np

# %%
data = pd.read_csv('listings.csv')
data.head(10)
# Out:
#          id                            listing_url       scrape_id  \
# 0  17629440  https://www.airbnb.com/rooms/17629440  20220911230914
# 1      2737      https://www.airbnb.com/rooms/2737  20220911230914
# 2    103870    https://www.airbnb.com/rooms/103870  20220911230914
# 3      2903      https://www.airbnb.com/rooms/2903  20220911230914
# 4    104339    https://www.airbnb.com/rooms/104339  20220911230914
# 5      3079      https://www.airbnb.com/rooms/3079  20220911230914
# 6     11834     https://www.airbnb.com/rooms/11834  20220911230914
# 7     12398     https://www.airbnb.com/rooms/12398  20220911230914
# 8    105153    https://www.airbnb.com/rooms/105153  20220911230914
# 9    108035    https://www.airbnb.com/rooms/108035  20220911230914
#
#   last_scraped           source                                       name  \
# 0   2022-09-12      city scrape                            ISOLA DEL CUORE
# 1   2022-09-12      city scrape           Elif's room in cozy, clean flat.
# ...
